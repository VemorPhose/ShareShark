# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/raw/NSE.csv')
df = df[df['instrument_type'] == 'EQUITY']
df.head()
# Out:
#          instrument_key  exchange_token tradingsymbol  \
# 2   NSE_EQ|INE869I01013           21195          GTPL
# 7   NSE_EQ|INE399C01030           11689      SUPRAJIT
# 8   NSE_EQ|INE0MJQ01020           12986       PRITIKA
# 9   NSE_EQ|INE0LLY01014           27213          EIEL
# 10  NSE_EQ|INE0J1E01027           10293           KCK
#
#                         name  last_price expiry  strike  tick_size  lot_size  \
# 2       GTPL HATHWAY LIMITED      119.06    NaN     NaN       0.01       1.0
# 7   SUPRAJIT ENGINEERING LTD      462.15    NaN     NaN       0.05       1.0
# 8      PRITIKA ENG COMPO LTD       76.80    NaN     NaN       0.05    2000.0
# 9   ENVIRO INFRA ENGINEERS L      235.40    NaN     NaN       0.01       1.0
# 10        KCK INDUSTRIES LTD       44.35    NaN     NaN       0.05    2500.0
#
#    instrument_type option_type exchange
# 2           EQUITY         NaN   NSE_EQ
# 7           EQUITY         NaN   NSE_EQ
# 8           EQUITY         NaN   NSE_EQ
# ...
